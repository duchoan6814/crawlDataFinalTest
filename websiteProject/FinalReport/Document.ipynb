# %% [markdown]
# <h1 align="center">Báo cáo cuối khóa (Nhóm 7)</h1>

# %% [markdown]
# <h2>I. Thông tin nhóm:</h2>
# <ol>
#     <li>
#         <b>Nguyễn Bùi Duy Sơn</b>
#         <ul>
#             <li>K12 <b>Đại Học Công nghiệp tp.HCM</b></li>
#             <li>Chuyên ngành kỹ thuật phần mềm</li>
#         </ul>
#     </li>
#     <li>
#         <b>Trương Đức Hoàn</b>
#         <ul>
#             <li>K14 <b>Đại Học Công nghiệp tp.HCM</b></li>
#             <li>Chuyên ngành kỹ thuật phần mềm</li>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# <h2>II. Hoạt động của nhóm</h2>
# <ol>
#     <li>
#         họp lần 1:
#         <ul>
#             <li>Diễn ra sau khi nhận bài tập lớn từ thầy.</li>
#             <li>Hình thức họp: họp online qua nền tảng zoom.</li>
#             <li>
#                 Nội dung:
#                 <ul type="-">
#                     <li>Hai anh em làm quen với nhau.</li>
#                     <li>Tìm và phân tích đề tài.</li>
#                     <li>Lên kế hoạc cho việc crawl data.
#                 </ul>
#             </li>
#         </ul>
#     </li>
#     <li>
#         họp lần 2:
#         <ul>
#             <li>Diễn ra sau khi đã thu thập đầy đủ data cần thiết.</li>
#             <li>Hình thức họp: họp offline tại quán cafe.</li>
#             <li>
#                 Nội dung:
#                 <ul type="-">
#                     <li>Phân tích data thu thập được.</li>
#                     <li>Phân tích các hình thực trực quan cho dữ liệu thu thập được như sử dụng biểu đồ nào cho loại data nào....</li>
#                     <li>Giải đáp thắc mắc khó khăn.</li>
#                 </ul>
#             </li>
#         </ul>
#     </li>
#     <li>
#         họp lần 4:
#         <ul>
#             <li>Diễn ra sau khi gần hoàn thành việc trực quan dữ liệu và nhận được yêu cầu viết Document cho bài báo cáo.</li>
#             <li>Hình thức họp: họp offline tại quán cafe.</li>
#             <li>
#                 Nội dung:
#                 <ul type="-">
#                     <li>Demo kết quả làm được.</li>
#                     <li>Phân tích việc soạn powerpoint và viết document cho bài báo cáo</li>
#                 </ul>
#             </li>
#         </ul>
#     </li>
# </ol>

# %% [markdown]
# <h2>III. Đề tài và lý do chọn đề tài</h2>

# %% [markdown]
# <h3>1. Đề tài 1 (Trương Đức Hoàn)</h3>
# <ul>
#     <li>
#         Giới thiệu đề tài:
#         <ul>
#             <li>
#                 Đề tài đầu tiên nhóm chọn liên quan đến một website bất kì, nhóm đã quyết định lựa chọn trang web <a href="https://itviec.com/it-jobs">Itviec.com</a>. Đây là một trang web để tìm các công việc liên quan đến IT ở Việt Nam, các nhà tuyển dụng có thể đăng thông tin lên trang tuyển dụng này và người cần tìm việc cũng có thể lên trang này để tìm việc, nó như một cái cầu nối để đem nhà tuyển dụng với người lao động trong ngành IT đến gần nhau hơn. Ở đây người lao động cũng có thể đăng thông tin như CV lên trang web để cho các nhà tuyển dụng vào coi thông tin và có thể gửi ofer đến người lao động một các nhanh chóng và thuận lợi.Ngoài việc kết nối giữa nhà tuyển dụng và người lao động thì website còn cung cấp một blog với rất nhiều thông tin thú vị về ngành cho chúng ta.
#             </li>
#         </ul>
#     </li>
#     <li>
#         Lý do chọn đề tài:
#         <ul>
#             <li>Website có rất nhiều công việc để khai thác.</li>
#             <li>Mỗi một chi tiết công việc thì trong đó lại có rất nhiều các trường thông thông tin có thể dễ dàng trực quan được.</li>
#             <li>Các trường thông tin được ràng buộc nên rất dễ để phân tích dữ liệu.</li>
#             <li>Ngoài những lý do trên nhóm muốn dựa vào website này để có thể trực quan những dữ liệu thu thập được từ website để từ đó đưa ra được cái nhìn trực quan, tổng quát về ngành IT tại việt Nam hiện nay.</li>
#         </ul>
#     </li>
#
# </ul>
#
# <h3>2. Đề tài 2 (Nguyễn Bùi Duy Sơn)</h3>
# <ul>
#     <li>
#         Giới thiệu đề tài:
#         <ul>
#             <li>
#                 Đối với chủ đề một group của <b>trường Đại học công nghiệp tp.HCM</b> thì sau một thời gian tìm tòi phân tích nhóm đã lựa trọn được một nhóm có tên là "<a href="https://www.facebook.com/groups/iuh2020">IUH - Chào Tân Sinh Viên 2020</a>". Thì đây là một group do <b>trường đại học công nghiệp tp.HCM</b> lập ra nhằm tư vấn giải đáp thắc mắc cho các bạn sinh viên tương lai có mong muốn đăng ký theo học tại trường. Tất cả mọi người có nhu cầu đăng ký vào trường trong năm nay hoặc thời gian tới, có bất kì thắc mắc nào từ điểm thi, các ngành học, thủ tục nhập học, rồi thậm trí cuộc sống sinh viên,... thì có thể đặt câu hỏi trên nhóm này và sẽ được các admin của nhóm hoặc là các anh chị đi trước vào tư vấn giải đáp các thắc mắc của các bạn.
#             </li>
#         </ul>
#     </li>
#     <li>
#         Lý do chọn đề tài:
#         <ul>
#             <li>Đây là một nhóm mới và nhận được sự quan tâm rất nhiều của các bạn muốn đăng ký vào trường đặc biệt là các bạn học sinh 12 sắp chuẩn bị bưới chân vào ngưỡng cửa đại học và phải chọn cho mình một ngôi trường phù hợp đề đầu tư cho tương lai của mình.</li>
#             <li>Dựa vào các câu hỏi và mức độ tương tác giữa các bài đăng trên đó thì có thể phân tích được vấn đề gì đang được các bạn có nguyện vọng vào trường quan tâm nhất. Để từ đó nhà trường có thể đưa ra giải đáp và các thắc mắc đó một cách chi tiết nhất tới các bạn.</li>
#         </ul>
#     </li>
#
# </ul>

# %% [markdown]
# <h2>IV. Trình bày đề tài</h2>

# %% [markdown]
# <h3>1. Đề tài Website Itviec.com</h3>
# <ol>
#     <li>
#         Cách làm
#         <ul>
#             <li>
#                 Phân tích website
#                 <ul>
#                     <li>
#                         Đầu tiên sau khi nhật task em đã tiến hành phân tích trang web, khảo sát sơ lược về trang web coi trang web có những trường thông tin nào dùng được và không dùng được đề từ đó đưa ra các phương hướng cho việc crawl data cũng như trực quan hóa dữ liệu sau này.
#                     </li>
#                     <li>
#                         Thấy được website này sử dụng <b>show more</b> để render thêm dữ liệu lên trang web chứ không phải sử dụng phương thức phân trang như những trang web khác thường dùng nên em sẽ lựa chọn selenium để crawl dữ liệu.
#                     </li>
#                     <li>
#                         Vì website render các component lên 1 page như vậy nên ý tưởng crawl data của em ở đây sẽ là lấy hết danh sách các link dẫn tới các trang chi tiết công việc, sau đó dùng vòng lặp lặp qua hết các trang chi tiết công việc đó để lấy các trường dữ liệu cần thiết.
#                     </li>
#                     <li>
#                         Trang chi tiết công việc có rất nhiều trường thông tin nhưng phần lớn là các trường thông tin có sử dụng ngôn ngữ tự nhiên như các trường thông tin giới thiệu về công việc hay những yêu cầu của công việc. Ngôn ngữ tự nhiên rất khó xử lý nên em sẽ lựa chọn các trường dữ liệu dễ sử dụng hơn như các công nghệ yêu cầu, lương, ngày làm việc, tên công việc, tên công ty, công ty đó thuộc quốc gia nào,...Những trường dữ liệu này có thể sẽ dễ xử lý  để phù hợp với yêu cầu trực quan dữ liệu của mình sau này.
#                     </li>
#                 </ul>
#             </li>
#             <li>
#                 Crawl data
#                 <ul>
#                     <li>
#                         Khi đã phân tích kỹ càng rồi em tiến hành crawl data, do trước đó em đã crawl data của Facabook rồi mà trang web này cũng tương tự như Facebook vậy nên việc crwal data tương đối là nhẹ nhàng.
#                     </li>
#                     <li>
#                         Sau quá trình crawl data thì em thu được một file Json là một danh sách bao gồm 1260 job công việc các trường thông tin cần thiết mà em đã phân tích ở trên.
#                     </li>
#                 </ul>
#             </li>
#             <li>
#                 Visualization
#                 <ul>
#                     <li>
#                         Thời gian và kiến thức đối với việc phân tích và trực quan dữ liệu chưa nhiều nên em sẽ sử dụng một số trường thông tin cơ bản để phân tích và trực quan hóa các dữ liệu đó lên một các trực quan nhất để chuyền tải đến mọi người.
#                     </li>
#                     <li>
#                         Các trường dữ liệu được sử dụng ở đây như là
#                 </ul>
#             </li>
#         </ul>
#     </li>
#     <li>Khó khăn</li>
#     <li>Kết quả</li>
# </ol>

# %% [markdown]
# <h3>VI. Tổng kết</h3>
# <p>
#     Sau khi kết thúc khóa học crawl data do thầy Tình tổ chức cái mà nhóm nhận được không chỉ là kỹ năng crawl data, mà còn là các kỹ năng khác như kỹ năng phân tích dữ liệu, kỹ năng trực quan hóa dữ liệu, kỹ năng làm việc nhóm,... Tất cả đều là những kỹ năng cần thiết cho lập trình viên ngày nay, bây giờ em có thể vận dụng những kỹ năng đã học được để áp dụng vào công việc và học tập. Nhóm xin gửi lời cảm ơn tới thầy Tình đã tổ chức khóa tạo ra môi trường học tập bổ ích trong giai đoạn Covid-19 để sau giai đoạn cách ly, các bạn sẽ học được thêm các kỹ năng mới. Tiếp theo là gửi lời cảm ơn đến các bạn mentor đã tận tình hướng dẫn, Mong muốn trong tương lai sẽ tiếp tục được đồng hành với mọi người, được tìm hiểu thêm về DATA và được học tập thêm nhiều kỹ năng mới.
# </p>
